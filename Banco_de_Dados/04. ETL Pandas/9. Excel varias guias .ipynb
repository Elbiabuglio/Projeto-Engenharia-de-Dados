# %%
import pandas as pd

# %%
# extração padrão
df = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx") 
display(df)
# Out:
#     Vendedor  Vendas
# 0     Lucas      625
# 1      Maria     594
# 2    Natália     650
# 3   Henrique     862
# 4     marcos     452
# 5      Paula     139
# 6    Juliano     175
# 7   Gabriela     293
# 8      Brian     529
# 9      Diego     507
# 10     kátia     705

# %%
# extração selecionando guia espesifica (sheet_name + nome da guia excel)
df = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" ,sheet_name='Produto2' ) 
display(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # extração selecionando guia espesifica (sheet_name + nome da guia excel)
# ----> 2 df = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" ,sheet_name='Produto2' )
#       3 display(df)
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
# ...

# %%
# extração selecionando guia espesifica (sheet_name + nome da guia excel)
TabelaProduto = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Planilha2')
display(TabelaProduto)
# Out:
#    Titulo mesclado  Unnamed: 1
# 0               NaN        NaN
# 1               NaN        NaN
# 2              Loja     Vendas
# 3           Niterói        625
# 4          Curitiba        594
# 5    Rio de Janeiro        650
# 6         São Paulo        862
# 7            Cuiabá        452
# 8            Palmas        139
# 9          Teresina        175
# 10           Recife        293
# 11   Santa Catarina        529
# 12           Manaus        507
# 13   Belo Horizonte        705

# %%
# extração selecionando guia espesifica + pula linha (sheet_name + nome da guia excel + skiprows pula quantas linhas quiser )
#skiprows pula linha
tabelaProduto = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Planilha2',skiprows=3)
display(tabelaProduto)
# Out:
#               Loja  Vendas
# 0          Niterói     625
# 1         Curitiba     594
# 2   Rio de Janeiro     650
# 3        São Paulo     862
# 4           Cuiabá     452
# 5           Palmas     139
# 6         Teresina     175
# 7           Recife     293
# 8   Santa Catarina     529
# 9           Manaus     507
# 10  Belo Horizonte     705

# %%
# escolhendo coluns espefificas (usecols  )
tabelaProduto2 = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Vendas')
display(tabelaProduto2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 # escolhendo coluns espefificas (usecols  )
# ----> 2 tabelaProduto2 = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Vendas')
#       3 display(tabelaProduto2)
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
# ...

# %%
# escolhendo coluns espefificas (usecols)
produto = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Vendas',usecols='A:B')
display(produto)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 # escolhendo coluns espefificas (usecols)
# ----> 2 produto = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Vendas',usecols='A:B')
#       3 display(produto)
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
# ...

# %%
# escolhendo coluns espefificas (usecols  )
Loja = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Vendas',usecols= 'F:G')
display(Loja)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 # escolhendo coluns espefificas (usecols  )
# ----> 2 Loja = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Vendas',usecols= 'F:G')
#       3 display(Loja)
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
# ...

# %%
# escolhendo coluns espefificas (usecols  )
tabelaProduto2 = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Vendas')
display(tabelaProduto2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # escolhendo coluns espefificas (usecols  )
# ----> 2 tabelaProduto2 = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Vendas')
#       3 display(tabelaProduto2)
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
# ...

# %%
# escolhendo coluns espefificas (usecols)  + usando uma lista 
Produto = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Vendas',usecols= [0,1,2])
display(Produto)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 # escolhendo coluns espefificas (usecols)  + usando uma lista
# ----> 2 Produto = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Vendas',usecols= [0,1,2])
#       3 display(Produto)
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
# ...

# %%
# escolhendo coluns espefificas (usecols)  + usando uma lista 
Loja = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Vendas',usecols= [5,6,7])
display(Loja)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 # escolhendo coluns espefificas (usecols)  + usando uma lista
# ----> 2 Loja = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Vendas',usecols= [5,6,7])
#       3 display(Loja)
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
# ...

# %%
# escolhendo coluns espefificas    usecols + skiprows
planilha4 = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Planilha4')
display(planilha4)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
# escolhendo coluns espefificas    usecols + skiprows
planilha4 = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= "Planilha4",usecols="g:h",skiprows=7)
display(planilha4)
# Out:
#     Vendedor  Vendas
# 0     Lucas      625
# 1      Maria     594
# 2    Natália     650
# 3   Henrique     862
# 4     marcos     452
# 5      Paula     139
# 6    Juliano     175
# 7   Gabriela     293
# 8      Brian     529
# 9      Diego     507
# 10     kátia     705

# %%
#skiprows = pula linha 
#nrows = seleciona até a quantidade de linhas que voce quiser
LojaProduto = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Produto - Loja')
display(LojaProduto)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 #skiprows = pula linha
#       2 #nrows = seleciona até a quantidade de linhas que voce quiser
# ----> 3 LojaProduto = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Produto - Loja')
#       4 display(LojaProduto)
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
# ...

# %%
#skiprows = pula linha 
#nrows = seleciona até a quantidade de linhas que voce quiser 
produto = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Produto - Loja' , nrows= 11)
display(produto)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 3
#       1 #skiprows = pula linha
#       2 #nrows = seleciona até a quantidade de linhas que voce quiser
# ----> 3 produto = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Produto - Loja' , nrows= 11)
#       4 display(produto)
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
# ...

# %%
#skiprows = pula linha 
#nrows = seleciona até a quantidade de linhas que voce quiser 
Loja = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Produto - Loja' , skiprows= 13)
display(Loja)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 #skiprows = pula linha
#       2 #nrows = seleciona até a quantidade de linhas que voce quiser
# ----> 3 Loja = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Produto - Loja' , skiprows= 13)
#       4 display(Loja)
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
# ...

# %%
Loja = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Produto - Loja' ,usecols='G:H', skiprows=13)
display(Loja)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 Loja = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Produto - Loja' ,usecols='G:H', skiprows=13)
#       2 display(Loja)
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
# ...

# %%
Loja = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Produto - Loja' ,usecols='G:H', nrows=11)
display(Loja)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 Loja = pd.read_excel(r"C:\Users\Note reserva\Desktop\Python\arquivos_excel\Filante.xlsx" , sheet_name= 'Produto - Loja' ,usecols='G:H', nrows=11)
#       2 display(Loja)
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# ...
