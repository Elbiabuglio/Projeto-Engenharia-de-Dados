# %%
import pandas as pd
from sqlalchemy import create_engine,VARCHAR,NUMERIC,INTEGER,DATE,DATETIME,String,text

#Origem
conexaoDB = ('DRIVER={ODBC Driver 17 for SQL Server};''SERVER=localhost;''DATABASE=AdventureWorksDW2019;''Trusted_Connection=yes;')
engine = create_engine(f'mssql+pyodbc:///?odbc_connect={conexaoDB}')

query = '''
SELECT 
ProductKey
,ProductAlternateKey
,FrenchProductName
,EnglishProductName
,Color 
,StandardCost
  FROM [AdventureWorksDW2019].[dbo].[DimProduct]
  where StandardCost is not null

'''

df = pd.read_sql_query(query, engine)

# Exiba  DataFrame
engine.dispose()
df.head()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\Note reserva\Desktop\Curso Engenharia Dados\Python - SGBDS\sgbds\Lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# ...

# %% [markdown]
# Envio de dados para SQL Server

# %%
#Conexão envio
''' parametros para to_sql (enviar dados pra banco)
name = tabela destino
con = conexão
if_exists = se existir a tabela o que faço?  replace ou append
index= index do python df 
text = transformar strig de conexão em texto para sqlalchemy  reconhecer 
dtype = tipos das colunas de destino

'''

# %%
#conexao Destino - inferindo os tipos  dados 
conexao_destino = ('DRIVER={ODBC Driver 17 for SQL Server};''SERVER=localhost;''DATABASE=Python;''Trusted_Connection=yes;')
engine_destino = create_engine(f'mssql+pyodbc:///?odbc_connect={conexao_destino}')

tabela_destino= 'produto_etl'

tipo_colnas = {
    
    'ProductAlternateKey':VARCHAR(10),
    'Color':VARCHAR(15),
    'FrenchProductName':VARCHAR(50)
    }

df.to_sql(name= tabela_destino,con=engine_destino,if_exists='replace' ,index=False , dtype=tipo_colnas)

engine_destino.dispose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 14
#       5 tabela_destino= 'produto_etl'
#       7 tipo_colnas = {
#       8
#       9     'ProductAlternateKey':VARCHAR(10),
#      10     'Color':VARCHAR(15),
#      11     'FrenchProductName':VARCHAR(50)
#      12     }
# ---> 14 df.to_sql(nome= tabela_destino,con=engine_destino,if_exists='replace' ,index=False , dtype=tipo_colnas)
#      16 engine_destino.dispose()
#
# NameError: name 'df' is not defined

# %%
#conexao Destino
conexao_destino = ('DRIVER={ODBC Driver 17 for SQL Server};''SERVER=localhost;''DATABASE=Python;''Trusted_Connection=yes;')
engine_destino = create_engine(f'mssql+pyodbc:///?odbc_connect={conexao_destino}')

tabela_destino= 'produto_etl'

df.to_sql(name= tabela_destino,con=engine_destino,if_exists='replace' ,index=False )

engine_destino.dispose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 7
#       3 engine_destino = create_engine(f'mssql+pyodbc:///?odbc_connect={conexao_destino}')
#       5 tabela_destino= 'produto_etl'
# ----> 7 df.to_sql(name= tabela_destino,con=engine_destino,if_exists='replace' ,index=False )
#       9 engine_destino.dispose()
#
# NameError: name 'df' is not defined
