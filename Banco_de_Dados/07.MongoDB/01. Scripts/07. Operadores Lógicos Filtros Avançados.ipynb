# %%
from pymongo import MongoClient
import pandas   as pd 
pd.set_option('display.max_columns', None)  

client = MongoClient('mongodb+srv://user_Engenharia:1022@cluster0.haxoe.mongodb.net/')
db = client['Aula']
colletion= db.get_collection('anac')

filter={'$and':[{'UF':'MG'},{'Classificacao_da_Ocorrência':'Acidente'}]}
columns ={'Numero_da_Ocorrencia':1,'Classificacao_da_Ocorrência':1,'UF':1,'PSSO':1}

data = list(colletion.find(filter,columns))
df = pd.DataFrame(data)
df.head(5)
# Out:
#                         _id Numero_da_Ocorrencia Classificacao_da_Ocorrência  \
# 0  67b3fc07010f2554c8cfd491                 7759                    Acidente
# 1  67b3fc07010f2554c8cfd4a8                 7516                    Acidente
# 2  67b3fc07010f2554c8cfd4b1                 7511                    Acidente
# 3  67b3fc07010f2554c8cfd519                 7208                    Acidente
# 4  67b3fc07010f2554c8cfd579                 7703                    Acidente
#
#    UF        PSSO
# 0  MG  verdadeiro
# 1  MG       falso
# 2  MG  verdadeiro
# 3  MG  verdadeiro
# 4  MG  verdadeiro

# %%
from pymongo import MongoClient
import pandas   as pd 
pd.set_option('display.max_columns', None)  

client = MongoClient('mongodb+srv://user_Engenharia:1022@cluster0.haxoe.mongodb.net/')
db = client['Aula']
colletion= db.get_collection('anac')

filter={'$or':[{'UF':'GO'},{'PSSO':'verdadeiro'}]}
columns ={'Numero_da_Ocorrencia':1,'Classificacao_da_Ocorrência':1,'UF':1,'PSSO':1}

data = list(colletion.find(filter,columns))
df = pd.DataFrame(data)
df.head(35)
# Out:
#                          _id Numero_da_Ocorrencia Classificacao_da_Ocorrência  \
# 0   67b3fc07010f2554c8cfd490                 7762                   Incidente
# 1   67b3fc07010f2554c8cfd491                 7759                    Acidente
# 2   67b3fc07010f2554c8cfd492                 7758                    Acidente
# 3   67b3fc07010f2554c8cfd493                 7758                    Acidente
# 4   67b3fc07010f2554c8cfd494                 7757             Incidente Grave
# 5   67b3fc07010f2554c8cfd496                 5118                    Acidente
# 6   67b3fc07010f2554c8cfd499                 7754             Incidente Grave
# 7   67b3fc07010f2554c8cfd49a                 7754             Incidente Grave
# 8   67b3fc07010f2554c8cfd49b                 7753                    Acidente
# 9   67b3fc07010f2554c8cfd49d                 5665                    Acidente
# 10  67b3fc07010f2554c8cfd49f                 7526                   Incidente
# 11  67b3fc07010f2554c8cfd4a1                 7524          Ocorrência de Solo
# 12  67b3fc07010f2554c8cfd4a2                 7523                   Incidente
# 13  67b3fc07010f2554c8cfd4a3                 7522                    Acidente
# 14  67b3fc07010f2554c8cfd4a5                 7520                   Incidente
# 15  67b3fc07010f2554c8cfd4a6                 7519                   Incidente
# 16  67b3fc07010f2554c8cfd4a7                 7518                   Incidente
# 17  67b3fc07010f2554c8cfd4a9                 7514                   Incidente
# 18  67b3fc07010f2554c8cfd4aa                 7517                   Incidente
# 19  67b3fc07010f2554c8cfd4ab                 7515             Incidente Grave
# 20  67b3fc07010f2554c8cfd4ac                 7229                   Incidente
# 21  67b3fc07010f2554c8cfd4ad                 7228                   Incidente
# 22  67b3fc07010f2554c8cfd4ae                 7227          Ocorrência de Solo
# 23  67b3fc07010f2554c8cfd4af                 7513                   Incidente
# 24  67b3fc07010f2554c8cfd4b1                 7511                    Acidente
# 25  67b3fc07010f2554c8cfd4b2                 7510                   Incidente
# 26  67b3fc07010f2554c8cfd4b3                 7236                   Incidente
# 27  67b3fc07010f2554c8cfd4b5                 7234                   Incidente
# 28  67b3fc07010f2554c8cfd4b6                 7233                    Acidente
# 29  67b3fc07010f2554c8cfd4b7                 7232                    Acidente
# 30  67b3fc07010f2554c8cfd4b8                 7231                   Incidente
# 31  67b3fc07010f2554c8cfd4b9                 7230                   Incidente
# 32  67b3fc07010f2554c8cfd4ba                 7226                   Incidente
# 33  67b3fc07010f2554c8cfd4bb                 7225                    Acidente
# 34  67b3fc07010f2554c8cfd4bc                 7224                    Acidente
#
#                UF        PSSO
# 0              SP  verdadeiro
# 1              MG  verdadeiro
# 2              GO  verdadeiro
# 3              GO  verdadeiro
# 4              RS  verdadeiro
# 5              ES  verdadeiro
# 6              SP  verdadeiro
# 7              SP  verdadeiro
# 8              SP  verdadeiro
# 9   Indeterminado  verdadeiro
# 10             MG  verdadeiro
# 11             RJ  verdadeiro
# 12             SP  verdadeiro
# 13             RR  verdadeiro
# 14             SP  verdadeiro
# 15             PR  verdadeiro
# 16             PR  verdadeiro
# 17             SC  verdadeiro
# 18             PE  verdadeiro
# 19             MT  verdadeiro
# 20             RJ  verdadeiro
# 21             SP  verdadeiro
# 22             RJ  verdadeiro
# 23             PR  verdadeiro
# 24             MG  verdadeiro
# 25             MG  verdadeiro
# 26             MG  verdadeiro
# 27             BA  verdadeiro
# 28             MS  verdadeiro
# 29             AM  verdadeiro
# 30             SC  verdadeiro
# 31             ES  verdadeiro
# 32             MG  verdadeiro
# 33             GO       falso
# 34             SP  verdadeiro
