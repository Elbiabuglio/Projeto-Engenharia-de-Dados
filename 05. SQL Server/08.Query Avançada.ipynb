# %%
import pandas as pd
import pyodbc 

server = 'localhost' # Substitua pelo nome do servidor SQL Server
database = 'Python'  # Substitua pelo nome do banco de dados
conexaoDB = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};'
                      f'SERVER={server};'
                      f'DATABASE={database};'
                      'Trusted_Connection=yes;')

cursor = conexaoDB.cursor()   # criando cursor de comando '

# %%
Query = """

select 
t1.id as IdVenda
,t3.Nome as Produto
,t4.Categoria
,t1.total_price
,t2.status
,t2.created_at
,t5.first_name as NomeCliente
,t5.email
,t5.cell_phone as Telefone
,t5.state as Estado
from [dbo].[Items]									as T1	
Left Join  [dbo].[Ordens]						as T2 on t1.order_id = t2.id
Left join [dbo].[Produtos]					as T3 on t1.product_id= t3.ID
Left join [dbo].[Categoria]					as T4 on t3.Id_Category = t4.ID
Left join [dbo].[Clientes]				        as T5 on t2.customer_id = t5.id


"""

# %%
Join = pd.read_sql(Query,conexaoDB)
Join.head(10)
# Out:
# C:\Users\Note reserva\AppData\Local\Temp\ipykernel_8476\2881997810.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Join = pd.read_sql(Query,conexaoDB)
#    IdVenda              Produto Categoria  total_price    status  \
# 0    10682  Máquina Fotográfica         7        377.0  entregue
# 1    10682  Máquina Fotográfica         7        377.0  entregue
# 2    15650      Hidratante caro         1         10.0  entregue
# 3    15650      Hidratante caro         1         10.0  entregue
# 4    19082  A Comédia Engraçada         3         20.0  entregue
# 5    19082  A Comédia Engraçada         3         20.0  entregue
# 6    26312  O Romance Exagerado         3         92.0  entregue
# 7    26312  O Romance Exagerado         3         92.0  entregue
# 8    26347           Chiai-homi         4       2304.0  entregue
# 9    26347           Chiai-homi         4       2304.0  entregue
#
#            created_at NomeCliente             email     Telefone  \
# 0 2019-08-28 03:36:31      Daniel  daniel@teste.com  9 4761-6557
# 1 2019-08-28 03:36:31      Daniel  daniel@teste.com  9 4761-6557
# 2 2019-08-28 03:36:31      Daniel  daniel@teste.com  9 4761-6557
# 3 2019-08-28 03:36:31      Daniel  daniel@teste.com  9 4761-6557
# 4 2019-08-28 03:36:31      Daniel  daniel@teste.com  9 4761-6557
# 5 2019-08-28 03:36:31      Daniel  daniel@teste.com  9 4761-6557
# 6 2019-08-28 03:36:31      Daniel  daniel@teste.com  9 4761-6557
# 7 2019-08-28 03:36:31      Daniel  daniel@teste.com  9 4761-6557
# 8 2019-08-28 03:36:31      Daniel  daniel@teste.com  9 4761-6557
# 9 2019-08-28 03:36:31      Daniel  daniel@teste.com  9 4761-6557
#
#                 Estado
# 0  Rio Grande do Norte
# 1  Rio Grande do Norte
# 2  Rio Grande do Norte
# 3  Rio Grande do Norte
# 4  Rio Grande do Norte
# 5  Rio Grande do Norte
# 6  Rio Grande do Norte
# 7  Rio Grande do Norte
# 8  Rio Grande do Norte
# 9  Rio Grande do Norte
